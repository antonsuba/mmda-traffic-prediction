# %%
import pandas as pd
Meta = pd.read_csv('data/clean_train_data.csv')
import numpy as np
from sklearn.cross_validation import train_test_split
y = Meta.pop('Classification')
X = Meta
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, stratify = y)

# %%
df = pd.read_csv('data/clean_train_data.csv')

# %%
df1 = df.loc[df['Classification'] == 1]
df2 = df[df['Classification'] == 2]
df3 = df[df['Classification'] == 3]
df1
# Out:
#         Unnamed: 0  Bike   Bus       Car  Classification  DriversInjured  \
# 0                0     0  0.00  0.055556             1.0             0.0
# 1                1     0  0.00  0.111111             1.0             0.0
# 3                3     0  0.00  0.055556             1.0             0.0
# 4                4     0  0.00  0.000000             1.0             0.0
# 6                6     0  0.00  0.055556             1.0             0.0
# 7                7     0  0.00  0.000000             1.0             0.0
# 8                8     0  0.00  0.055556             1.0             0.0
# 9                9     0  0.00  0.111111             1.0             0.0
# 10              10     0  0.00  0.111111             1.0             0.0
# 11              11     0  0.00  0.055556             1.0             0.0
# 12              12     0  0.00  0.055556             1.0             0.0
# 14              14     0  0.00  0.055556             1.0             0.0
# ...

# %%
df4 = df1.sample(70)
df5 = df2.sample(25)
df6 = df3.sample(5)
df4
# Out:
#         Unnamed: 0  Bike   Bus       Car  Classification  DriversInjured  \
# 509739      509739     0  0.00  0.000000             1.0             0.0
# 31206        31206     0  0.00  0.166667             1.0             0.0
# 506984      506984     0  0.00  0.055556             1.0             0.0
# 715412      715412     0  0.00  0.055556             1.0             0.0
# 143719      143719     0  0.00  0.055556             1.0             0.0
# 815884      815884     0  0.00  0.055556             1.0             0.0
# 318423      318423     0  0.00  0.055556             1.0             0.0
# 866665      866665     0  0.00  0.055556             1.0             0.0
# 166552      166552     0  0.00  0.000000             1.0             0.0
# 544623      544623     0  0.00  0.055556             1.0             0.0
# 391079      391079     0  0.00  0.000000             1.0             0.0
# 195239      195239     0  0.00  0.000000             1.0             0.0
# ...

# %%
df7 = df5.append(df6)
df8 = df4.append(df7)
df8
# Out:
#         Unnamed: 0  Bike   Bus       Car  Classification  DriversInjured  \
# 509739      509739     0  0.00  0.000000             1.0        0.000000
# 31206        31206     0  0.00  0.166667             1.0        0.000000
# 506984      506984     0  0.00  0.055556             1.0        0.000000
# 715412      715412     0  0.00  0.055556             1.0        0.000000
# 143719      143719     0  0.00  0.055556             1.0        0.000000
# 815884      815884     0  0.00  0.055556             1.0        0.000000
# 318423      318423     0  0.00  0.055556             1.0        0.000000
# 866665      866665     0  0.00  0.055556             1.0        0.000000
# 166552      166552     0  0.00  0.000000             1.0        0.000000
# 544623      544623     0  0.00  0.055556             1.0        0.000000
# 391079      391079     0  0.00  0.000000             1.0        0.000000
# 195239      195239     0  0.00  0.000000             1.0        0.000000
# ...

# %%
Meta2 = df8
y = Meta2.pop('Classification')
X = Meta2
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, stratify = y)

# %%
y_train.to_csv('y_train.csv')

# %%
y_train
# Out:
# 566276    2.0
# 31206     1.0
# 188168    2.0
# 677457    1.0
# 361379    3.0
# 440455    1.0
# 250460    2.0
# 83286     1.0
# 552758    1.0
# 801662    1.0
# 930753    1.0
# 90936     1.0
# 487367    1.0
# 692538    1.0
# 296245    2.0
# 866665    1.0
# 509739    1.0
# 79490     1.0
# 583838    2.0
# 140925    2.0
# 454349    2.0
# 8351      3.0
# 162504    3.0
# 146942    1.0
# 843625    1.0
# 195239    1.0
# 66782     2.0
# 606155    1.0
# 538776    3.0
# 318423    1.0
#          ...
# 214295    1.0
# 492917    2.0
# 188211    2.0
# 253282    1.0
# 36459     1.0
# 606889    1.0
# 571766    1.0
# 830891    1.0
# 134241    2.0
# 30481     1.0
# 715412    1.0
# 544623    1.0
# 760085    1.0
# 420166    1.0
# 819000    1.0
# 858953    1.0
# 856847    1.0
# 82481     1.0
# 833791    2.0
# 459168    2.0
# 282357    1.0
# 815884    1.0
# 912318    1.0
# 187158    2.0
# 87580     1.0
# 598893    1.0
# 76654     1.0
# 549975    1.0
# 296412    1.0
# 143719    1.0
# ...
